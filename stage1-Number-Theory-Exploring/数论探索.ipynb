# %%
def next_prime_delta(x):
    return next_prime(x)-x
def previous_prime_delta(x):
    return previous_prime(x)-x

# %% [markdown]
# NextPrime-Square-Inequality; **` next_prime_delta(n^2) <= 1+euler_phi(n) `**

# %%
[(n,euler_phi(n),next_prime_delta(n^2)) for n in range(1,50)]
# Out:
# [(1, 1, 1),
#  (2, 1, 1),
#  (3, 2, 2),
#  (4, 2, 1),
#  (5, 4, 4),
#  (6, 2, 1),
#  (7, 6, 4),
#  (8, 4, 3),
#  (9, 6, 2),
#  (10, 4, 1),
#  (11, 10, 6),
#  (12, 4, 5),
#  (13, 12, 4),
#  (14, 6, 1),
#  (15, 8, 2),
#  (16, 8, 1),
#  (17, 16, 4),
#  (18, 6, 7),
#  (19, 18, 6),
#  (20, 8, 1),
#  (21, 12, 2),
#  (22, 10, 3),
#  (23, 22, 12),
#  (24, 8, 1),
#  (25, 20, 6),
#  (26, 12, 1),
#  (27, 18, 4),
#  (28, 12, 3),
#  (29, 28, 12),
#  (30, 8, 7),
#  (31, 30, 6),
#  (32, 16, 7),
#  (33, 20, 2),
#  (34, 16, 7),
#  (35, 24, 4),
#  (36, 12, 1),
#  (37, 36, 4),
#  (38, 18, 3),
#  (39, 24, 2),
#  (40, 16, 1),
#  (41, 40, 12),
#  (42, 12, 13),
#  (43, 42, 12),
#  (44, 20, 13),
#  (45, 24, 2),
#  (46, 22, 13),
#  (47, 46, 4),
#  (48, 16, 5),
#  (49, 42, 10)]

# %%
list_plot([next_prime_delta(n^2) for n in range(1,500)], color='green', pointsize=5)
# Out:
# Graphics object consisting of 1 graphics primitive
